# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\__init__.py:465
#     451         raise ImportError(textwrap.dedent('''
#     452             Failed to load PyTorch C extensions:
#     453                 It appears that PyTorch has loaded the `torch/_C` folder
#    (...)
#     461                 or by running Python from a different directory.
#     462             ''').strip()) from None
#     463     raise  # If __file__ is not None the cause is unknown, so just re-raise.
# --> 465 for name in dir(_C):
#     466     if name[0] != '_' and not name.endswith('Base'):
#     467         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\admin\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[6], line 1
#     import pandas as pd
#
#   File c:\Users\admin\anaconda3\Lib\site-packages\pandas\__init__.py:27
#     __import__(_dependency)
#
#   File <string>
# SyntaxError: source code string cannot contain null bytes
